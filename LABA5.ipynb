# %%
# Task 5. Graphics
import pyreadr as pr
import pandas as pd
from matplotlib import pyplot as plt

data1: pd.DataFrame = pr.read_r("C:/Users/moroz/Music/summarySCC_PM25.rds")[None]
data2: pd.DataFrame = pr.read_r("C:/Users/moroz/Music/Source_Classification_Code.rds")[None]

# %%
pip install pyreadr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data1.groupby("year", as_index=False).sum("Emissions").plot(x="year", y="Emissions", kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data1[data1["fips"] == "24510"].groupby("year", as_index=False).sum("Emissions") \
    .plot(x="year", y="Emissions", kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
fig, ax = plt.subplots(2, 2)
for i, t in enumerate(df1["type"].drop_duplicates().tolist()):
    data1[data1["type"] == t].groupby("year", as_index=False).sum("Emissions") \
        .plot(x="year", y="Emissions", kind="bar", ax=ax[int(i / 2), i % 2])
    ax[int(i / 2), i % 2].set_title(t)

root = [i for i in df2[["SCC", "EI.Sector"]].to_dict().values()]
root = {root[0][i]: root[1][i] for i in range(len(root[0]))}
data12 = data1.apply(lambda x: x.apply(lambda y: root[y]) if x.name == "SCC" else x)

# %%
data12[data12["SCC"].str.contains("Coal")] \
    .groupby("year", as_index=False) \
    .sum("Emissions") \
    .plot(x="year", y="Emissions", kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data12[(data12["SCC"].str.startswith("Mobile")) & (data12["fips"] == "24510")] \
    .groupby("year", as_index=False) \
    .sum("Emissions") \
    .plot(x="year", y="Emissions", kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data12[(data12["SCC"].str.startswith("Mobile")) & (data12["fips"] == "06037")] \
    .groupby("year", as_index=False) \
    .sum("Emissions") \
    .plot(x="year", y="Emissions", kind="bar")

plt.show()
